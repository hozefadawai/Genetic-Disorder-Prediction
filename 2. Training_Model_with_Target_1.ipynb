# %% [markdown]
# # Training Model with Target 1

# %%
from sklearn.model_selection import RandomizedSearchCV,GridSearchCV
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier as RFC
from sklearn.svm import SVC
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression as LR
import lightgbm as LGBM

# %% [markdown]
# #### Random Forest Classifier

# %%
clf = RFC(random_state=42)
params = {
    'max_depth': [2, 3, 5, 8, 10, 12, 20],
    'min_samples_leaf': [5, 10, 20, 50, 80],
    'criterion': ["gini", "entropy"]
}
clf= RandomizedSearchCV(clf, params,verbose=10,n_jobs=-1)
clf.fit(x_train_smote1, y_train_smote1)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# RandomizedSearchCV(estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [2, 3, 5, 8, 10, 12, 20],
#                                         'min_samples_leaf': [5, 10, 20, 50,
#                                                              80]},
#                    verbose=10)

# %%
print(clf.best_estimator_)
# Out:
# RandomForestClassifier(max_depth=20, min_samples_leaf=5, random_state=42)

# %%
print(clf.best_score_)
# Out:
# 0.6992893517644496

# %%
clf = RFC(criterion='entropy', max_depth=20,
                            min_samples_leaf=5, random_state=42)

clf.fit(x_train_smote1,y_train_smote1)
clf = CalibratedClassifierCV(clf, method="sigmoid")
clf.fit(x_train_smote1,y_train_smote1)

predict_y =clf.predict(x_train_smote1)
train_RFC_target1 = f1_score(y_train_smote1, predict_y, average='macro')
print ('The train f1_macro is:',f1_score(y_train_smote1, predict_y,average='macro'))

predict_y = clf.predict(x_val_smote1)
val_RFC_target1 = f1_score(y_val_smote1, predict_y, average='macro')
print('The cross validation f1_macro is:',f1_score(y_val_smote1, predict_y,average='macro'))
# Out:
# The train f1_macro is: 0.885287817946931
# The cross validation f1_macro is: 0.6903847502158951

# %% [markdown]
# ####Decision Tree classifier

# %%
clf = DecisionTreeClassifier(random_state=42)
params = {
    'max_depth': [2, 3, 5, 8, 10, 12, 20],
    'min_samples_leaf': [5, 10, 20, 50, 80],
    'criterion': ["gini", "entropy"]
}
clf= GridSearchCV(clf, params, verbose=10, n_jobs=-1)
clf.fit(x_train_smote1, y_train_smote1)
# Out:
# Fitting 5 folds for each of 70 candidates, totalling 350 fits
# GridSearchCV(estimator=DecisionTreeClassifier(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 5, 8, 10, 12, 20],
#                          'min_samples_leaf': [5, 10, 20, 50, 80]},
#              verbose=10)

# %%
print(clf.best_estimator_)
# Out:
# DecisionTreeClassifier(max_depth=12, min_samples_leaf=5, random_state=42)

# %%
print(clf.best_score_)
# Out:
# 0.6348534871562654

# %%
clf = DecisionTreeClassifier(criterion='entropy', max_depth=12,
                            min_samples_leaf=20, random_state=42)
clf.fit(x_train_smote1,y_train_smote1)
clf = CalibratedClassifierCV(clf, method="sigmoid")
clf.fit(x_train_smote1,y_train_smote1)
predict_y =clf.predict(x_train_smote1)

train_DT_target1 = f1_score(y_train_smote1, predict_y, average='macro')
print ('The train f1_macro is:',f1_score(y_train_smote1, predict_y,average='macro'))

predict_y = clf.predict(x_val_smote1)
val_DT_target1 = f1_score(y_val_smote1, predict_y, average='macro')
print('The cross validation f1_macro is:',f1_score(y_val_smote1, predict_y,average='macro'))
# Out:
# The train f1_macro is: 0.7555122895818899
# The cross validation f1_macro is: 0.6468112964305858

# %% [markdown]
# ####LGBM

# %%
clf = LGBM.LGBMClassifier(random_state=42)     # to balance the data setting is_unbalance to true

# setting parameters
params = {'max_depth':[4, 5, 6, 8, 10, 12], # max_depth shallow because it was overfitting the model very badly
          'num_leaves': [40, 60, 80, 100, 120],
          'min_samples_leaf': [10, 15, 20, 25, 30, 40],
          'learning_rate': [0.02, 0.05, 0.1, 0.2],
          'n_estimators': [50, 100, 150, 200, 300]} # keeping learning_rate low to penalize it more and to avoid overfit

# we use GridSearchCv method
# we take CV=3 to to get better results
clf= RandomizedSearchCV(clf, params, cv=10, scoring= 'f1_macro', return_train_score=True, n_jobs = -1)
clf.fit(x_train_smote1, y_train_smote1)        # we will fit vectorized x_train_tfidf to train and cross validating our data
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=40. Current value: min_data_in_leaf=40
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=40. Current value: min_data_in_leaf=40
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004985 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6309
# [LightGBM] [Info] Number of data points in the train set: 23667, number of used features: 30
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# RandomizedSearchCV(cv=10, estimator=LGBMClassifier(random_state=42), n_jobs=-1,
#                    param_distributions={'learning_rate': [0.02, 0.05, 0.1, 0.2],
#                                         'max_depth': [4, 5, 6, 8, 10, 12],
#                                         'min_samples_leaf': [10, 15, 20, 25, 30,
#                                                              40],
#                                         'n_estimators': [50, 100, 150, 200,
#                                                          300],
#                                         'num_leaves': [40, 60, 80, 100, 120]},
#                    return_train_score=True, scoring='f1_macro')

# %%
# printing best parameters
clf.best_params_
# Out:
# {'num_leaves': 60,
#  'n_estimators': 300,
#  'min_samples_leaf': 40,
#  'max_depth': 12,
#  'learning_rate': 0.05}

# %%
# now we have got best hyperparameter from train and cross validation data
clf = LGBM.LGBMClassifier(learning_rate= 0.05,
                          max_depth= 12,
                          min_samples_leaf = 80,
                          num_leaves= 250,
                          random_state=42)
# we will again train our train data with best hyperparameter
clf.fit(x_train_smote1,y_train_smote1)
clf = CalibratedClassifierCV(clf, method="sigmoid")
clf.fit(x_train_smote1,y_train_smote1)

predict_y = clf.predict(x_train_smote1)
train_LGBM_target1 = f1_score(y_train_smote1, predict_y, average='macro')
print ('The train f1_macro is:', f1_score(y_train_smote1, predict_y, average='macro'))

predict_y = clf.predict(x_val_smote1)
val_LGBM_target1 = f1_score(y_val_smote1, predict_y, average='macro')
print('The cross validation f1_macro is:',f1_score(y_val_smote1, predict_y, average='macro'))
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=80. Current value: min_data_in_leaf=80
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=80. Current value: min_data_in_leaf=80
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004971 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6309
# [LightGBM] [Info] Number of data points in the train set: 23667, number of used features: 30
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=80. Current value: min_data_in_leaf=80
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=80. Current value: min_data_in_leaf=80
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004142 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6310
# [LightGBM] [Info] Number of data points in the train set: 18933, number of used features: 30
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=80. Current value: min_data_in_leaf=80
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=80. Current value: min_data_in_leaf=80
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=80. Current value: min_data_in_leaf=80
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004760 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6275
# [LightGBM] [Info] Number of data points in the train set: 18933, number of used features: 30
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=80. Current value: min_data_in_leaf=80
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=80. Current value: min_data_in_leaf=80
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=80. Current value: min_data_in_leaf=80
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=80. Current value: min_data_in_leaf=80
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=80. Current value: min_data_in_leaf=80
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=80. Current value: min_data_in_leaf=80
# The train f1_macro is: 0.865544629248436
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=80. Current value: min_data_in_leaf=80
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=80. Current value: min_data_in_leaf=80
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=80. Current value: min_data_in_leaf=80
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=80. Current value: min_data_in_leaf=80
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=80. Current value: min_data_in_leaf=80
# The cross validation f1_macro is: 0.6970339761068153

# %% [markdown]
# ####AutoML

# %%
# !pip install flaml
from flaml import AutoML
# Out:
# Collecting flaml
#   Downloading FLAML-2.0.2-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.3/295.3 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: NumPy>=1.17.0rc1 in /usr/local/lib/python3.10/dist-packages (from flaml) (1.23.5)
# Installing collected packages: flaml
# Successfully installed flaml-2.0.2

# %%
clf = AutoML()
automl_settings = {
    "time_budget": 1600,  # in seconds
    "metric": 'macro_f1',
    "task": 'classification'
}

clf.fit(x_train_smote1, np.array(y_train_smote1).ravel(),
        **automl_settings)   # we will again train our train data with best hyperparameter
# Out:
# [flaml.automl.logger: 09-09 15:04:12] {1679} INFO - task = classification
# [flaml.automl.logger: 09-09 15:04:12] {1690} INFO - Evaluation method: cv
# [flaml.automl.logger: 09-09 15:04:12] {1788} INFO - Minimizing error metric: 1-macro_f1
# [flaml.automl.logger: 09-09 15:04:12] {1900} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'lrl1']
# [flaml.automl.logger: 09-09 15:04:12] {2218} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 09-09 15:04:14] {2344} INFO - Estimated sufficient time budget=23826s. Estimated necessary time budget=549s.
# [flaml.automl.logger: 09-09 15:04:14] {2391} INFO -  at 2.7s,	estimator lgbm's best error=0.4851,	best estimator lgbm's best error=0.4851
# [flaml.automl.logger: 09-09 15:04:14] {2218} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 09-09 15:04:15] {2391} INFO -  at 3.4s,	estimator lgbm's best error=0.4688,	best estimator lgbm's best error=0.4688
# [flaml.automl.logger: 09-09 15:04:15] {2218} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 09-09 15:04:16] {2391} INFO -  at 4.0s,	estimator lgbm's best error=0.4688,	best estimator lgbm's best error=0.4688
# [flaml.automl.logger: 09-09 15:04:16] {2218} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 09-09 15:04:17] {2391} INFO -  at 5.1s,	estimator lgbm's best error=0.4344,	best estimator lgbm's best error=0.4344
# [flaml.automl.logger: 09-09 15:04:17] {2218} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 09-09 15:04:17] {2391} INFO -  at 5.7s,	estimator lgbm's best error=0.4344,	best estimator lgbm's best error=0.4344
# [flaml.automl.logger: 09-09 15:04:17] {2218} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 09-09 15:04:18] {2391} INFO -  at 6.9s,	estimator lgbm's best error=0.4013,	best estimator lgbm's best error=0.4013
# [flaml.automl.logger: 09-09 15:04:18] {2218} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 09-09 15:04:20] {2391} INFO -  at 7.9s,	estimator lgbm's best error=0.4013,	best estimator lgbm's best error=0.4013
# [flaml.automl.logger: 09-09 15:04:20] {2218} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 09-09 15:04:20] {2391} INFO -  at 8.6s,	estimator lgbm's best error=0.4013,	best estimator lgbm's best error=0.4013
# [flaml.automl.logger: 09-09 15:04:20] {2218} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 09-09 15:04:23] {2391} INFO -  at 11.4s,	estimator lgbm's best error=0.3839,	best estimator lgbm's best error=0.3839
# [flaml.automl.logger: 09-09 15:04:23] {2218} INFO - iteration 9, current learner xgboost
# [flaml.automl.logger: 09-09 15:04:24] {2391} INFO -  at 12.3s,	estimator xgboost's best error=0.4936,	best estimator lgbm's best error=0.3839
# [flaml.automl.logger: 09-09 15:04:24] {2218} INFO - iteration 10, current learner xgboost
# [flaml.automl.logger: 09-09 15:04:27] {2391} INFO -  at 15.8s,	estimator xgboost's best error=0.4918,	best estimator lgbm's best error=0.3839
# [flaml.automl.logger: 09-09 15:04:27] {2218} INFO - iteration 11, current learner lgbm
# [flaml.automl.logger: 09-09 15:04:29] {2391} INFO -  at 17.8s,	estimator lgbm's best error=0.3839,	best estimator lgbm's best error=0.3839
# [flaml.automl.logger: 09-09 15:04:29] {2218} INFO - iteration 12, current learner lgbm
# [flaml.automl.logger: 09-09 15:04:56] {2391} INFO -  at 44.7s,	estimator lgbm's best error=0.3439,	best estimator lgbm's best error=0.3439
# [flaml.automl.logger: 09-09 15:04:56] {2218} INFO - iteration 13, current learner extra_tree
# [flaml.automl.logger: 09-09 15:04:57] {2391} INFO -  at 45.0s,	estimator extra_tree's best error=0.5345,	best estimator lgbm's best error=0.3439
# [flaml.automl.logger: 09-09 15:04:57] {2218} INFO - iteration 14, current learner extra_tree
# [flaml.automl.logger: 09-09 15:04:57] {2391} INFO -  at 45.4s,	estimator extra_tree's best error=0.4709,	best estimator lgbm's best error=0.3439
# [flaml.automl.logger: 09-09 15:04:57] {2218} INFO - iteration 15, current learner extra_tree
# [flaml.automl.logger: 09-09 15:04:57] {2391} INFO -  at 45.7s,	estimator extra_tree's best error=0.4709,	best estimator lgbm's best error=0.3439
# [flaml.automl.logger: 09-09 15:04:57] {2218} INFO - iteration 16, current learner extra_tree
# [flaml.automl.logger: 09-09 15:04:58] {2391} INFO -  at 46.2s,	estimator extra_tree's best error=0.4605,	best estimator lgbm's best error=0.3439
# [flaml.automl.logger: 09-09 15:04:58] {2218} INFO - iteration 17, current learner rf
# [flaml.automl.logger: 09-09 15:04:58] {2391} INFO -  at 46.6s,	estimator rf's best error=0.5104,	best estimator lgbm's best error=0.3439
# [flaml.automl.logger: 09-09 15:04:58] {2218} INFO - iteration 18, current learner rf
# [flaml.automl.logger: 09-09 15:04:59] {2391} INFO -  at 47.1s,	estimator rf's best error=0.4622,	best estimator lgbm's best error=0.3439
# [flaml.automl.logger: 09-09 15:04:59] {2218} INFO - iteration 19, current learner rf
# [flaml.automl.logger: 09-09 15:04:59] {2391} INFO -  at 47.5s,	estimator rf's best error=0.4622,	best estimator lgbm's best error=0.3439
# [flaml.automl.logger: 09-09 15:04:59] {2218} INFO - iteration 20, current learner rf
# [flaml.automl.logger: 09-09 15:05:00] {2391} INFO -  at 48.2s,	estimator rf's best error=0.4494,	best estimator lgbm's best error=0.3439
# [flaml.automl.logger: 09-09 15:05:00] {2218} INFO - iteration 21, current learner rf
# [flaml.automl.logger: 09-09 15:05:00] {2391} INFO -  at 48.8s,	estimator rf's best error=0.4494,	best estimator lgbm's best error=0.3439
# [flaml.automl.logger: 09-09 15:05:00] {2218} INFO - iteration 22, current learner lgbm
# [flaml.automl.logger: 09-09 15:05:34] {2391} INFO -  at 82.3s,	estimator lgbm's best error=0.3003,	best estimator lgbm's best error=0.3003
# [flaml.automl.logger: 09-09 15:05:34] {2218} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 09-09 15:05:54] {2391} INFO -  at 102.7s,	estimator lgbm's best error=0.3003,	best estimator lgbm's best error=0.3003
# [flaml.automl.logger: 09-09 15:05:54] {2218} INFO - iteration 24, current learner extra_tree
# [flaml.automl.logger: 09-09 15:05:55] {2391} INFO -  at 103.1s,	estimator extra_tree's best error=0.4605,	best estimator lgbm's best error=0.3003
# [flaml.automl.logger: 09-09 15:05:55] {2218} INFO - iteration 25, current learner extra_tree
# [flaml.automl.logger: 09-09 15:05:56] {2391} INFO -  at 103.9s,	estimator extra_tree's best error=0.4500,	best estimator lgbm's best error=0.3003
# [flaml.automl.logger: 09-09 15:05:56] {2218} INFO - iteration 26, current learner lgbm
# [flaml.automl.logger: 09-09 15:06:20] {2391} INFO -  at 128.7s,	estimator lgbm's best error=0.3003,	best estimator lgbm's best error=0.3003
# [flaml.automl.logger: 09-09 15:06:20] {2218} INFO - iteration 27, current learner extra_tree
# [flaml.automl.logger: 09-09 15:06:21] {2391} INFO -  at 129.2s,	estimator extra_tree's best error=0.4500,	best estimator lgbm's best error=0.3003
# [flaml.automl.logger: 09-09 15:06:21] {2218} INFO - iteration 28, current learner extra_tree
# [flaml.automl.logger: 09-09 15:06:23] {2391} INFO -  at 131.3s,	estimator extra_tree's best error=0.4116,	best estimator lgbm's best error=0.3003
# [flaml.automl.logger: 09-09 15:06:23] {2218} INFO - iteration 29, current learner extra_tree
# [flaml.automl.logger: 09-09 15:06:24] {2391} INFO -  at 132.3s,	estimator extra_tree's best error=0.4116,	best estimator lgbm's best error=0.3003
# [flaml.automl.logger: 09-09 15:06:24] {2218} INFO - iteration 30, current learner lgbm
# [flaml.automl.logger: 09-09 15:06:57] {2391} INFO -  at 165.6s,	estimator lgbm's best error=0.3003,	best estimator lgbm's best error=0.3003
# [flaml.automl.logger: 09-09 15:06:57] {2218} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 09-09 15:08:15] {2391} INFO -  at 243.0s,	estimator lgbm's best error=0.3003,	best estimator lgbm's best error=0.3003
# [flaml.automl.logger: 09-09 15:08:15] {2218} INFO - iteration 32, current learner rf
# [flaml.automl.logger: 09-09 15:08:15] {2391} INFO -  at 243.9s,	estimator rf's best error=0.4494,	best estimator lgbm's best error=0.3003
# [flaml.automl.logger: 09-09 15:08:15] {2218} INFO - iteration 33, current learner extra_tree
# [flaml.automl.logger: 09-09 15:08:17] {2391} INFO -  at 245.3s,	estimator extra_tree's best error=0.4116,	best estimator lgbm's best error=0.3003
# [flaml.automl.logger: 09-09 15:08:17] {2218} INFO - iteration 34, current learner lgbm
# [flaml.automl.logger: 09-09 15:08:32] {2391} INFO -  at 260.7s,	estimator lgbm's best error=0.3003,	best estimator lgbm's best error=0.3003
# [flaml.automl.logger: 09-09 15:08:32] {2218} INFO - iteration 35, current learner extra_tree
# [flaml.automl.logger: 09-09 15:08:34] {2391} INFO -  at 262.2s,	estimator extra_tree's best error=0.3935,	best estimator lgbm's best error=0.3003
# [flaml.automl.logger: 09-09 15:08:34] {2218} INFO - iteration 36, current learner extra_tree
# [flaml.automl.logger: 09-09 15:08:35] {2391} INFO -  at 263.2s,	estimator extra_tree's best error=0.3935,	best estimator lgbm's best error=0.3003
# [flaml.automl.logger: 09-09 15:08:35] {2218} INFO - iteration 37, current learner xgboost
# [flaml.automl.logger: 09-09 15:08:36] {2391} INFO -  at 263.9s,	estimator xgboost's best error=0.4887,	best estimator lgbm's best error=0.3003
# [flaml.automl.logger: 09-09 15:08:36] {2218} INFO - iteration 38, current learner extra_tree
# [flaml.automl.logger: 09-09 15:08:38] {2391} INFO -  at 266.4s,	estimator extra_tree's best error=0.3892,	best estimator lgbm's best error=0.3003
# [flaml.automl.logger: 09-09 15:08:38] {2218} INFO - iteration 39, current learner rf
# [flaml.automl.logger: 09-09 15:08:38] {2391} INFO -  at 266.9s,	estimator rf's best error=0.4494,	best estimator lgbm's best error=0.3003
# [flaml.automl.logger: 09-09 15:08:38] {2218} INFO - iteration 40, current learner xgboost
# [flaml.automl.logger: 09-09 15:08:39] {2391} INFO -  at 267.7s,	estimator xgboost's best error=0.4437,	best estimator lgbm's best error=0.3003
# [flaml.automl.logger: 09-09 15:08:39] {2218} INFO - iteration 41, current learner xgboost
# [flaml.automl.logger: 09-09 15:08:40] {2391} INFO -  at 268.5s,	estimator xgboost's best error=0.4353,	best estimator lgbm's best error=0.3003
# [flaml.automl.logger: 09-09 15:08:40] {2218} INFO - iteration 42, current learner lgbm
# [flaml.automl.logger: 09-09 15:09:37] {2391} INFO -  at 325.4s,	estimator lgbm's best error=0.2933,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:09:37] {2218} INFO - iteration 43, current learner xgboost
# [flaml.automl.logger: 09-09 15:09:38] {2391} INFO -  at 326.2s,	estimator xgboost's best error=0.4250,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:09:38] {2218} INFO - iteration 44, current learner extra_tree
# [flaml.automl.logger: 09-09 15:09:39] {2391} INFO -  at 327.5s,	estimator extra_tree's best error=0.3869,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:09:39] {2218} INFO - iteration 45, current learner xgboost
# [flaml.automl.logger: 09-09 15:09:42] {2391} INFO -  at 330.4s,	estimator xgboost's best error=0.4187,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:09:42] {2218} INFO - iteration 46, current learner rf
# [flaml.automl.logger: 09-09 15:09:43] {2391} INFO -  at 331.6s,	estimator rf's best error=0.4121,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:09:43] {2218} INFO - iteration 47, current learner xgboost
# [flaml.automl.logger: 09-09 15:09:45] {2391} INFO -  at 333.5s,	estimator xgboost's best error=0.3662,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:09:45] {2218} INFO - iteration 48, current learner rf
# [flaml.automl.logger: 09-09 15:09:46] {2391} INFO -  at 334.1s,	estimator rf's best error=0.4121,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:09:46] {2218} INFO - iteration 49, current learner xgboost
# [flaml.automl.logger: 09-09 15:09:47] {2391} INFO -  at 335.7s,	estimator xgboost's best error=0.3662,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:09:47] {2218} INFO - iteration 50, current learner xgboost
# [flaml.automl.logger: 09-09 15:09:50] {2391} INFO -  at 338.5s,	estimator xgboost's best error=0.3414,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:09:50] {2218} INFO - iteration 51, current learner rf
# [flaml.automl.logger: 09-09 15:09:52] {2391} INFO -  at 340.0s,	estimator rf's best error=0.4121,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:09:52] {2218} INFO - iteration 52, current learner rf
# [flaml.automl.logger: 09-09 15:09:53] {2391} INFO -  at 341.9s,	estimator rf's best error=0.3801,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:09:53] {2218} INFO - iteration 53, current learner rf
# [flaml.automl.logger: 09-09 15:09:54] {2391} INFO -  at 342.7s,	estimator rf's best error=0.3801,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:09:54] {2218} INFO - iteration 54, current learner lgbm
# [flaml.automl.logger: 09-09 15:10:13] {2391} INFO -  at 361.1s,	estimator lgbm's best error=0.2933,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:10:13] {2218} INFO - iteration 55, current learner xgboost
# [flaml.automl.logger: 09-09 15:10:16] {2391} INFO -  at 364.5s,	estimator xgboost's best error=0.3414,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:10:16] {2218} INFO - iteration 56, current learner rf
# [flaml.automl.logger: 09-09 15:10:18] {2391} INFO -  at 366.8s,	estimator rf's best error=0.3701,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:10:18] {2218} INFO - iteration 57, current learner rf
# [flaml.automl.logger: 09-09 15:10:20] {2391} INFO -  at 368.0s,	estimator rf's best error=0.3690,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:10:20] {2218} INFO - iteration 58, current learner xgboost
# [flaml.automl.logger: 09-09 15:10:21] {2391} INFO -  at 369.6s,	estimator xgboost's best error=0.3414,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:10:21] {2218} INFO - iteration 59, current learner lgbm
# [flaml.automl.logger: 09-09 15:10:37] {2391} INFO -  at 385.8s,	estimator lgbm's best error=0.2933,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:10:37] {2218} INFO - iteration 60, current learner xgboost
# [flaml.automl.logger: 09-09 15:10:44] {2391} INFO -  at 392.7s,	estimator xgboost's best error=0.3231,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:10:44] {2218} INFO - iteration 61, current learner rf
# [flaml.automl.logger: 09-09 15:10:46] {2391} INFO -  at 394.7s,	estimator rf's best error=0.3690,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:10:46] {2218} INFO - iteration 62, current learner xgboost
# [flaml.automl.logger: 09-09 15:10:51] {2391} INFO -  at 399.5s,	estimator xgboost's best error=0.3140,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:10:51] {2218} INFO - iteration 63, current learner xgboost
# [flaml.automl.logger: 09-09 15:10:56] {2391} INFO -  at 404.8s,	estimator xgboost's best error=0.3140,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:10:56] {2218} INFO - iteration 64, current learner lgbm
# [flaml.automl.logger: 09-09 15:12:30] {2391} INFO -  at 498.4s,	estimator lgbm's best error=0.2933,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:12:30] {2218} INFO - iteration 65, current learner xgboost
# [flaml.automl.logger: 09-09 15:12:32] {2391} INFO -  at 500.0s,	estimator xgboost's best error=0.3140,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:12:32] {2218} INFO - iteration 66, current learner xgboost
# [flaml.automl.logger: 09-09 15:12:39] {2391} INFO -  at 507.7s,	estimator xgboost's best error=0.3120,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:12:39] {2218} INFO - iteration 67, current learner xgboost
# [flaml.automl.logger: 09-09 15:12:42] {2391} INFO -  at 510.1s,	estimator xgboost's best error=0.3120,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:12:42] {2218} INFO - iteration 68, current learner lgbm
# [flaml.automl.logger: 09-09 15:13:40] {2391} INFO -  at 568.6s,	estimator lgbm's best error=0.2933,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:13:40] {2218} INFO - iteration 69, current learner extra_tree
# [flaml.automl.logger: 09-09 15:13:43] {2391} INFO -  at 571.1s,	estimator extra_tree's best error=0.3869,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:13:43] {2218} INFO - iteration 70, current learner xgb_limitdepth
# [flaml.automl.logger: 09-09 15:13:50] {2391} INFO -  at 578.7s,	estimator xgb_limitdepth's best error=0.3321,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:13:50] {2218} INFO - iteration 71, current learner xgb_limitdepth
# [flaml.automl.logger: 09-09 15:13:57] {2391} INFO -  at 585.3s,	estimator xgb_limitdepth's best error=0.3321,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:13:57] {2218} INFO - iteration 72, current learner xgb_limitdepth
# [flaml.automl.logger: 09-09 15:14:04] {2391} INFO -  at 592.2s,	estimator xgb_limitdepth's best error=0.3248,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:14:04] {2218} INFO - iteration 73, current learner xgb_limitdepth
# [flaml.automl.logger: 09-09 15:14:13] {2391} INFO -  at 601.3s,	estimator xgb_limitdepth's best error=0.3248,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:14:13] {2218} INFO - iteration 74, current learner extra_tree
# [flaml.automl.logger: 09-09 15:14:14] {2391} INFO -  at 602.5s,	estimator extra_tree's best error=0.3562,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:14:14] {2218} INFO - iteration 75, current learner extra_tree
# [flaml.automl.logger: 09-09 15:14:15] {2391} INFO -  at 603.6s,	estimator extra_tree's best error=0.3562,	best estimator lgbm's best error=0.2933
# [flaml.automl.logger: 09-09 15:14:15] {2218} INFO - iteration 76, current learner xgboost
# [flaml.automl.logger: 09-09 15:14:38] {2391} INFO -  at 626.3s,	estimator xgboost's best error=0.2925,	best estimator xgboost's best error=0.2925
# [flaml.automl.logger: 09-09 15:14:38] {2218} INFO - iteration 77, current learner xgboost
# [flaml.automl.logger: 09-09 15:14:41] {2391} INFO -  at 629.5s,	estimator xgboost's best error=0.2925,	best estimator xgboost's best error=0.2925
# [flaml.automl.logger: 09-09 15:14:41] {2218} INFO - iteration 78, current learner extra_tree
# [flaml.automl.logger: 09-09 15:14:42] {2391} INFO -  at 630.3s,	estimator extra_tree's best error=0.3562,	best estimator xgboost's best error=0.2925
# [flaml.automl.logger: 09-09 15:14:42] {2218} INFO - iteration 79, current learner xgboost
# [flaml.automl.logger: 09-09 15:17:04] {2391} INFO -  at 772.6s,	estimator xgboost's best error=0.2822,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:17:04] {2218} INFO - iteration 80, current learner xgboost
# [flaml.automl.logger: 09-09 15:17:54] {2391} INFO -  at 822.7s,	estimator xgboost's best error=0.2822,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:17:54] {2218} INFO - iteration 81, current learner xgb_limitdepth
# [flaml.automl.logger: 09-09 15:18:03] {2391} INFO -  at 831.8s,	estimator xgb_limitdepth's best error=0.3248,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:18:03] {2218} INFO - iteration 82, current learner extra_tree
# [flaml.automl.logger: 09-09 15:18:06] {2391} INFO -  at 834.3s,	estimator extra_tree's best error=0.3524,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:18:06] {2218} INFO - iteration 83, current learner extra_tree
# [flaml.automl.logger: 09-09 15:18:09] {2391} INFO -  at 837.3s,	estimator extra_tree's best error=0.3338,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:18:09] {2218} INFO - iteration 84, current learner extra_tree
# [flaml.automl.logger: 09-09 15:18:11] {2391} INFO -  at 839.8s,	estimator extra_tree's best error=0.3338,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:18:11] {2218} INFO - iteration 85, current learner extra_tree
# [flaml.automl.logger: 09-09 15:18:16] {2391} INFO -  at 844.3s,	estimator extra_tree's best error=0.3338,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:18:16] {2218} INFO - iteration 86, current learner extra_tree
# [flaml.automl.logger: 09-09 15:18:19] {2391} INFO -  at 846.9s,	estimator extra_tree's best error=0.3280,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:18:19] {2218} INFO - iteration 87, current learner extra_tree
# [flaml.automl.logger: 09-09 15:18:23] {2391} INFO -  at 851.3s,	estimator extra_tree's best error=0.3280,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:18:23] {2218} INFO - iteration 88, current learner xgboost
# [flaml.automl.logger: 09-09 15:20:35] {2391} INFO -  at 983.7s,	estimator xgboost's best error=0.2822,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:20:35] {2218} INFO - iteration 89, current learner xgboost
# [flaml.automl.logger: 09-09 15:22:23] {2391} INFO -  at 1091.1s,	estimator xgboost's best error=0.2822,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:22:23] {2218} INFO - iteration 90, current learner xgb_limitdepth
# [flaml.automl.logger: 09-09 15:22:25] {2391} INFO -  at 1093.3s,	estimator xgb_limitdepth's best error=0.3248,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:22:25] {2218} INFO - iteration 91, current learner xgboost
# [flaml.automl.logger: 09-09 15:24:02] {2391} INFO -  at 1190.8s,	estimator xgboost's best error=0.2822,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:24:02] {2218} INFO - iteration 92, current learner xgb_limitdepth
# [flaml.automl.logger: 09-09 15:24:22] {2391} INFO -  at 1210.4s,	estimator xgb_limitdepth's best error=0.3196,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:24:22] {2218} INFO - iteration 93, current learner extra_tree
# [flaml.automl.logger: 09-09 15:24:25] {2391} INFO -  at 1213.1s,	estimator extra_tree's best error=0.3173,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:24:25] {2218} INFO - iteration 94, current learner extra_tree
# [flaml.automl.logger: 09-09 15:24:26] {2391} INFO -  at 1214.8s,	estimator extra_tree's best error=0.3173,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:24:26] {2218} INFO - iteration 95, current learner xgboost
# [flaml.automl.logger: 09-09 15:24:50] {2391} INFO -  at 1238.7s,	estimator xgboost's best error=0.2822,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:24:50] {2218} INFO - iteration 96, current learner xgb_limitdepth
# [flaml.automl.logger: 09-09 15:25:19] {2391} INFO -  at 1267.7s,	estimator xgb_limitdepth's best error=0.3177,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:25:19] {2218} INFO - iteration 97, current learner extra_tree
# [flaml.automl.logger: 09-09 15:25:21] {2391} INFO -  at 1269.3s,	estimator extra_tree's best error=0.3035,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:25:21] {2218} INFO - iteration 98, current learner extra_tree
# [flaml.automl.logger: 09-09 15:25:24] {2391} INFO -  at 1272.3s,	estimator extra_tree's best error=0.3035,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:25:24] {2218} INFO - iteration 99, current learner extra_tree
# [flaml.automl.logger: 09-09 15:25:25] {2391} INFO -  at 1273.7s,	estimator extra_tree's best error=0.2860,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:25:25] {2218} INFO - iteration 100, current learner extra_tree
# [flaml.automl.logger: 09-09 15:25:27] {2391} INFO -  at 1275.3s,	estimator extra_tree's best error=0.2824,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:25:27] {2218} INFO - iteration 101, current learner extra_tree
# [flaml.automl.logger: 09-09 15:25:28] {2391} INFO -  at 1276.7s,	estimator extra_tree's best error=0.2824,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:25:28] {2218} INFO - iteration 102, current learner extra_tree
# [flaml.automl.logger: 09-09 15:25:31] {2391} INFO -  at 1279.0s,	estimator extra_tree's best error=0.2824,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:25:31] {2218} INFO - iteration 103, current learner rf
# [flaml.automl.logger: 09-09 15:25:32] {2391} INFO -  at 1280.2s,	estimator rf's best error=0.3363,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:25:32] {2218} INFO - iteration 104, current learner extra_tree
# [flaml.automl.logger: 09-09 15:25:33] {2391} INFO -  at 1281.3s,	estimator extra_tree's best error=0.2824,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:25:33] {2218} INFO - iteration 105, current learner extra_tree
# [flaml.automl.logger: 09-09 15:25:35] {2391} INFO -  at 1283.4s,	estimator extra_tree's best error=0.2824,	best estimator xgboost's best error=0.2822
# [flaml.automl.logger: 09-09 15:25:35] {2218} INFO - iteration 106, current learner extra_tree
# [flaml.automl.logger: 09-09 15:25:37] {2391} INFO -  at 1285.4s,	estimator extra_tree's best error=0.2729,	best estimator extra_tree's best error=0.2729
# [flaml.automl.logger: 09-09 15:25:37] {2218} INFO - iteration 107, current learner extra_tree
# [flaml.automl.logger: 09-09 15:25:42] {2391} INFO -  at 1290.2s,	estimator extra_tree's best error=0.2589,	best estimator extra_tree's best error=0.2589
# [flaml.automl.logger: 09-09 15:25:42] {2218} INFO - iteration 108, current learner extra_tree
# [flaml.automl.logger: 09-09 15:25:44] {2391} INFO -  at 1292.0s,	estimator extra_tree's best error=0.2589,	best estimator extra_tree's best error=0.2589
# [flaml.automl.logger: 09-09 15:25:44] {2218} INFO - iteration 109, current learner extra_tree
# [flaml.automl.logger: 09-09 15:25:47] {2391} INFO -  at 1295.7s,	estimator extra_tree's best error=0.2589,	best estimator extra_tree's best error=0.2589
# [flaml.automl.logger: 09-09 15:25:47] {2218} INFO - iteration 110, current learner extra_tree
# [flaml.automl.logger: 09-09 15:25:56] {2391} INFO -  at 1304.5s,	estimator extra_tree's best error=0.2589,	best estimator extra_tree's best error=0.2589
# [flaml.automl.logger: 09-09 15:25:56] {2218} INFO - iteration 111, current learner rf
# [flaml.automl.logger: 09-09 15:25:57] {2391} INFO -  at 1305.3s,	estimator rf's best error=0.3363,	best estimator extra_tree's best error=0.2589
# [flaml.automl.logger: 09-09 15:25:57] {2218} INFO - iteration 112, current learner extra_tree
# [flaml.automl.logger: 09-09 15:26:12] {2391} INFO -  at 1320.4s,	estimator extra_tree's best error=0.2580,	best estimator extra_tree's best error=0.2580
# [flaml.automl.logger: 09-09 15:26:12] {2218} INFO - iteration 113, current learner extra_tree
# [flaml.automl.logger: 09-09 15:26:17] {2391} INFO -  at 1325.0s,	estimator extra_tree's best error=0.2580,	best estimator extra_tree's best error=0.2580
# [flaml.automl.logger: 09-09 15:26:17] {2218} INFO - iteration 114, current learner xgb_limitdepth
# [flaml.automl.logger: 09-09 15:26:38] {2391} INFO -  at 1346.2s,	estimator xgb_limitdepth's best error=0.3093,	best estimator extra_tree's best error=0.2580
# [flaml.automl.logger: 09-09 15:26:38] {2218} INFO - iteration 115, current learner rf
# [flaml.automl.logger: 09-09 15:26:38] {2391} INFO -  at 1346.8s,	estimator rf's best error=0.3363,	best estimator extra_tree's best error=0.2580
# [flaml.automl.logger: 09-09 15:26:38] {2218} INFO - iteration 116, current learner rf
# [flaml.automl.logger: 09-09 15:26:40] {2391} INFO -  at 1348.8s,	estimator rf's best error=0.3196,	best estimator extra_tree's best error=0.2580
# [flaml.automl.logger: 09-09 15:26:40] {2218} INFO - iteration 117, current learner extra_tree
# [flaml.automl.logger: 09-09 15:26:54] {2391} INFO -  at 1362.2s,	estimator extra_tree's best error=0.2580,	best estimator extra_tree's best error=0.2580
# [flaml.automl.logger: 09-09 15:26:54] {2218} INFO - iteration 118, current learner extra_tree
# [flaml.automl.logger: 09-09 15:27:07] {2391} INFO -  at 1374.9s,	estimator extra_tree's best error=0.2580,	best estimator extra_tree's best error=0.2580
# [flaml.automl.logger: 09-09 15:27:07] {2218} INFO - iteration 119, current learner rf
# [flaml.automl.logger: 09-09 15:27:09] {2391} INFO -  at 1377.7s,	estimator rf's best error=0.3080,	best estimator extra_tree's best error=0.2580
# [flaml.automl.logger: 09-09 15:27:09] {2218} INFO - iteration 120, current learner extra_tree
# [flaml.automl.logger: 09-09 15:27:41] {2391} INFO -  at 1409.2s,	estimator extra_tree's best error=0.2580,	best estimator extra_tree's best error=0.2580
# [flaml.automl.logger: 09-09 15:27:41] {2218} INFO - iteration 121, current learner extra_tree
# [flaml.automl.logger: 09-09 15:27:47] {2391} INFO -  at 1414.9s,	estimator extra_tree's best error=0.2580,	best estimator extra_tree's best error=0.2580
# [flaml.automl.logger: 09-09 15:27:47] {2218} INFO - iteration 122, current learner extra_tree
# [flaml.automl.logger: 09-09 15:28:02] {2391} INFO -  at 1430.9s,	estimator extra_tree's best error=0.2532,	best estimator extra_tree's best error=0.2532
# [flaml.automl.logger: 09-09 15:28:02] {2218} INFO - iteration 123, current learner extra_tree
# [flaml.automl.logger: 09-09 15:28:17] {2391} INFO -  at 1445.8s,	estimator extra_tree's best error=0.2532,	best estimator extra_tree's best error=0.2532
# [flaml.automl.logger: 09-09 15:28:17] {2218} INFO - iteration 124, current learner rf
# [flaml.automl.logger: 09-09 15:28:20] {2391} INFO -  at 1448.3s,	estimator rf's best error=0.3080,	best estimator extra_tree's best error=0.2532
# [flaml.automl.logger: 09-09 15:28:20] {2218} INFO - iteration 125, current learner rf
# [flaml.automl.logger: 09-09 15:28:23] {2391} INFO -  at 1451.4s,	estimator rf's best error=0.3080,	best estimator extra_tree's best error=0.2532
# [flaml.automl.logger: 09-09 15:28:23] {2218} INFO - iteration 126, current learner rf
# [flaml.automl.logger: 09-09 15:28:27] {2391} INFO -  at 1455.5s,	estimator rf's best error=0.3011,	best estimator extra_tree's best error=0.2532
# [flaml.automl.logger: 09-09 15:28:27] {2218} INFO - iteration 127, current learner rf
# [flaml.automl.logger: 09-09 15:28:31] {2391} INFO -  at 1459.3s,	estimator rf's best error=0.2996,	best estimator extra_tree's best error=0.2532
# [flaml.automl.logger: 09-09 15:28:31] {2218} INFO - iteration 128, current learner extra_tree
# [flaml.automl.logger: 09-09 15:28:48] {2391} INFO -  at 1476.8s,	estimator extra_tree's best error=0.2532,	best estimator extra_tree's best error=0.2532
# [flaml.automl.logger: 09-09 15:28:48] {2218} INFO - iteration 129, current learner xgb_limitdepth
# [flaml.automl.logger: 09-09 15:29:11] {2391} INFO -  at 1499.4s,	estimator xgb_limitdepth's best error=0.3046,	best estimator extra_tree's best error=0.2532
# [flaml.automl.logger: 09-09 15:29:11] {2218} INFO - iteration 130, current learner extra_tree
# [flaml.automl.logger: 09-09 15:29:24] {2391} INFO -  at 1512.3s,	estimator extra_tree's best error=0.2532,	best estimator extra_tree's best error=0.2532
# [flaml.automl.logger: 09-09 15:29:24] {2218} INFO - iteration 131, current learner extra_tree
# [flaml.automl.logger: 09-09 15:29:36] {2391} INFO -  at 1524.5s,	estimator extra_tree's best error=0.2532,	best estimator extra_tree's best error=0.2532
# [flaml.automl.logger: 09-09 15:29:36] {2218} INFO - iteration 132, current learner extra_tree
# [flaml.automl.logger: 09-09 15:29:55] {2391} INFO -  at 1543.6s,	estimator extra_tree's best error=0.2526,	best estimator extra_tree's best error=0.2526
# [flaml.automl.logger: 09-09 15:29:55] {2218} INFO - iteration 133, current learner rf
# [flaml.automl.logger: 09-09 15:29:58] {2391} INFO -  at 1546.0s,	estimator rf's best error=0.2996,	best estimator extra_tree's best error=0.2526
# [flaml.automl.logger: 09-09 15:29:58] {2218} INFO - iteration 134, current learner extra_tree
# [flaml.automl.logger: 09-09 15:30:29] {2391} INFO -  at 1577.4s,	estimator extra_tree's best error=0.2493,	best estimator extra_tree's best error=0.2493
# [flaml.automl.logger: 09-09 15:30:29] {2218} INFO - iteration 135, current learner lrl1
# INFO:flaml.tune.searcher.blendsearch:No low-cost partial config given to the search algorithm. For cost-frugal search, consider providing low-cost values for cost-related hps via 'low_cost_partial_config'. More info can be found at https://microsoft.github.io/FLAML/docs/FAQ#about-low_cost_partial_config-in-tune
# [flaml.automl.logger: 09-09 15:30:43] {2391} INFO -  at 1591.9s,	estimator lrl1's best error=0.4512,	best estimator extra_tree's best error=0.2493
# [flaml.automl.logger: 09-09 15:30:43] {2218} INFO - iteration 136, current learner rf
# [flaml.automl.logger: 09-09 15:30:48] {2391} INFO -  at 1596.0s,	estimator rf's best error=0.2996,	best estimator extra_tree's best error=0.2493
# [flaml.automl.logger: 09-09 15:30:48] {2218} INFO - iteration 137, current learner rf
# [flaml.automl.logger: 09-09 15:30:52] {2391} INFO -  at 1600.0s,	estimator rf's best error=0.2982,	best estimator extra_tree's best error=0.2493
# [flaml.automl.logger: 09-09 15:30:58] {2627} INFO - retrain extra_tree for 6.6s
# [flaml.automl.logger: 09-09 15:30:58] {2630} INFO - retrained model: ExtraTreesClassifier(criterion='entropy', max_features=0.27714026209389997,
#                      max_leaf_nodes=4428, n_estimators=186, n_jobs=-1,
#                      random_state=12032022)
# [flaml.automl.logger: 09-09 15:30:58] {1930} INFO - fit succeeded
# [flaml.automl.logger: 09-09 15:30:58] {1931} INFO - Time taken to find the best model: 1577.3573641777039

# %%
predict_y = clf.predict(x_train_smote1)
train_AutoML_target1 = f1_score(y_train_smote1, predict_y, average='macro')
print ('The train f1_macro is:', f1_score(y_train_smote1, predict_y,average='macro'))

predict_y = clf.predict(x_val_smote1)
val_AutoML_target1 = f1_score(y_val_smote1, predict_y, average='macro')
print('The cross validation f1_macro is:',f1_score(y_val_smote1, predict_y,average='macro'))
# Out:
# The train f1_macro is: 0.9803958758354012
# The cross validation f1_macro is: 0.6546255608903655
